# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
output_path = "output/sketches/"

# %%
import matplotlib.font_manager
x = [f.name for f in matplotlib.font_manager.fontManager.ttflist]
print(list(x))
# Out:
# ['STIXSizeFiveSym', 'STIXSizeTwoSym', 'cmb10', 'STIXNonUnicode', 'STIXSizeTwoSym', 'DejaVu Sans', 'DejaVu Serif', 'STIXSizeFourSym', 'STIXSizeThreeSym', 'cmmi10', 'DejaVu Sans Mono', 'STIXGeneral', 'DejaVu Sans', 'STIXSizeOneSym', 'STIXGeneral', 'cmex10', 'DejaVu Sans Mono', 'DejaVu Sans', 'cmr10', 'STIXSizeThreeSym', 'cmtt10', 'DejaVu Serif', 'cmss10', 'DejaVu Sans', 'DejaVu Sans Mono', 'STIXSizeOneSym', 'STIXSizeFourSym', 'STIXNonUnicode', 'STIXNonUnicode', 'DejaVu Serif Display', 'DejaVu Sans Display', 'DejaVu Serif', 'DejaVu Serif', 'STIXNonUnicode', 'DejaVu Sans Mono', 'cmsy10', 'STIXGeneral', 'STIXGeneral', 'Noto Sans Mandaic', 'Seravek', 'Devanagari MT', 'Noto Sans Hanifi Rohingya', 'Helvetica', 'Bodoni 72 Oldstyle', '.SF Georgian Rounded', 'Noteworthy', 'Noto Sans Psalter Pahlavi', 'Noto Sans Javanese', 'Roboto', 'Heiti TC', '.ThonburiUI', 'Noto Sans Lycian', 'Wingdings', 'Andale Mono', 'Snell Roundhand', 'Gurmukhi Sangam MN', 'Noto Sans Gothic', 'Avenir Next Condensed', 'Ave
# ...

# %%
x = np.linspace(0.1, 4, 100)
y = np.exp(x)

with plt.xkcd():
    plt.figure(figsize=(7, 5))
    plt.rcParams["font.family"] = "xkcd Script"
    plt.plot(x, np.exp(x) - 0.8, linewidth=3)
    plt.xlabel("Dataset Size", fontsize=16, fontweight="bold", labelpad=20)
    plt.ylabel("Model Performance", fontsize=16, fontweight="bold", labelpad=20)
    plt.title("Observed Data Scaling Law", fontsize=20, fontweight="bold", pad=20)

    # remove x and y axis labels
    plt.xticks([])
    plt.yticks([])

    # remove the top and right spines
    ax = plt.gca()
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    # increase thickness of x and y axis
    # ax.spines["bottom"].set_linewidth(3)
    # ax.spines["left"].set_linewidth(3)
    # ax.spines["left"].set_position(("data", 0))
    # ax.spines["bottom"].set_position(("data", 0))
    # ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False, markersize=10)
    # ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False, markersize=10)
    # plt.savefig(f"{output_path}dataset_scaling.png", dpi=300, bbox_inches="tight")
    plt.show()
